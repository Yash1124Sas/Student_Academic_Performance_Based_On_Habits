# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('student_habits_performance.csv')

# %%
df
# Out:
#     student_id   age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   NaN  Female                  0.0                 1.2
# 1        S1001  20.0  Female                  6.9                 2.8
# 2        S1002  21.0    Male                  1.4                 3.1
# 3        S1003  23.0  Female                  1.0                 3.9
# 4        S1004  19.0  Female                  5.0                 4.4
# ..         ...   ...     ...                  ...                 ...
# 995      S1995  21.0  Female                  2.6                 0.5
# 996      S1996  17.0  Female                  2.9                 1.0
# 997      S1997  20.0    Male                  3.0                 2.6
# 998      S1998  24.0    Male                  5.4                 4.1
# 999      S1999  19.0  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            999 non-null    float64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df['social_media_hours']=df['social_media_hours']+df['netflix_hours']

# %%
sns.boxplot(x=df['social_media_hours'])
# Out:
# <Axes: xlabel='social_media_hours'>

# %%
df.drop(columns=['student_id','netflix_hours'],axis=1,inplace=True)

# %%
df
# Out:
#       age  gender  study_hours_per_day  social_media_hours part_time_job  \
# 0     NaN  Female                  0.0                 2.3            No
# 1    20.0  Female                  6.9                 5.1            No
# 2    21.0    Male                  1.4                 4.4            No
# 3    23.0  Female                  1.0                 4.9            No
# 4    19.0  Female                  5.0                 4.9            No
# ..    ...     ...                  ...                 ...           ...
# 995  21.0  Female                  2.6                 2.1            No
# 996  17.0  Female                  2.9                 3.4           Yes
# 997  20.0    Male                  3.0                 3.9            No
# 998  24.0    Male                  5.4                 5.2           Yes
# 999  19.0  Female                  4.3                 4.8            No
#
#      attendance_percentage  sleep_hours diet_quality  exercise_frequency  \
# ...

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  \
# count  999.000000           1000.00000         1000.000000
# mean    20.495495              3.55010            4.325200
# std      2.307896              1.46889            1.599808
# min     17.000000              0.00000            0.200000
# 25%     18.500000              2.60000            3.300000
# 50%     20.000000              3.50000            4.400000
# 75%     23.000000              4.50000            5.400000
# max     24.000000              8.30000           10.100000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count            1000.000000  1000.000000         1000.000000
# mean               84.131700     6.470100            3.042000
# std                 9.399246     1.226377            2.025423
# min                56.000000     3.200000            0.000000
# 25%                78.000000     5.600000            1.000000
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.drop('age',axis=1,inplace=True)

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    gender  study_hours_per_day  social_media_hours part_time_job  \
# 0  Female                  0.0                 2.3            No
# 1  Female                  6.9                 5.1            No
# 2    Male                  1.4                 4.4            No
# 3  Female                  1.0                 4.9            No
# 4  Female                  5.0                 4.9            No
#
#    attendance_percentage  sleep_hours diet_quality  exercise_frequency  \
# 0                   85.0          8.0         Fair                   6
# 1                   97.3          4.6         Good                   6
# 2                   94.8          8.0         Poor                   1
# 3                   71.0          9.2         Poor                   4
# 4                   90.9          4.9         Fair                   3
#
#   parental_education_level internet_quality  mental_health_rating  \
# 0                   Master          Average                     8
# ...

# %%
cat_cols=['gender','part_time_job','diet_quality','parental_education_level','internet_quality','extracurricular_participation']
for col in cat_cols:
    sns.boxplot(y=df[col],x=df['exam_score'])
    plt.show()

# %%
sns.histplot(df['exam_score'],kde=True)
# Out:
# <Axes: xlabel='exam_score', ylabel='Count'>

# %%
df.head()
# Out:
#    gender  study_hours_per_day  social_media_hours part_time_job  \
# 0  Female                  0.0                 2.3            No
# 1  Female                  6.9                 5.1            No
# 2    Male                  1.4                 4.4            No
# 3  Female                  1.0                 4.9            No
# 4  Female                  5.0                 4.9            No
#
#    attendance_percentage  sleep_hours diet_quality  exercise_frequency  \
# 0                   85.0          8.0         Fair                   6
# 1                   97.3          4.6         Good                   6
# 2                   94.8          8.0         Poor                   1
# 3                   71.0          9.2         Poor                   4
# 4                   90.9          4.9         Fair                   3
#
#   parental_education_level internet_quality  mental_health_rating  \
# 0                   Master          Average                     8
# ...

# %%
num_cols=['study_hours_per_day','social_media_hours','attendance_percentage','sleep_hours','exercise_frequency','mental_health_rating']
for col in num_cols:
    sns.histplot(x=df[col],kde=True)
    plt.show()

# %%
df.head()
# Out:
#    gender  study_hours_per_day  social_media_hours part_time_job  \
# 0  Female                  0.0                 2.3            No
# 1  Female                  6.9                 5.1            No
# 2    Male                  1.4                 4.4            No
# 3  Female                  1.0                 4.9            No
# 4  Female                  5.0                 4.9            No
#
#    attendance_percentage  sleep_hours diet_quality  exercise_frequency  \
# 0                   85.0          8.0         Fair                   6
# 1                   97.3          4.6         Good                   6
# 2                   94.8          8.0         Poor                   1
# 3                   71.0          9.2         Poor                   4
# 4                   90.9          4.9         Fair                   3
#
#   parental_education_level internet_quality  mental_health_rating  \
# 0                   Master          Average                     8
# ...

# %%
X=df.drop('exam_score',axis=True)
y=df['exam_score']

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
columns=['gender','part_time_job','diet_quality','parental_education_level','internet_quality','extracurricular_participation']
Xlabeled=X.copy()
label_encoders={}
for i in columns:
    Xlabeled=pd.get_dummies(Xlabeled,drop_first=True)

# %%
Xlabeled.astype(int)
# Out:
#      study_hours_per_day  social_media_hours  attendance_percentage  \
# 0                      0                   2                     85
# 1                      6                   5                     97
# 2                      1                   4                     94
# 3                      1                   4                     71
# 4                      5                   4                     90
# ..                   ...                 ...                    ...
# 995                    2                   2                     77
# 996                    2                   3                     86
# 997                    3                   3                     61
# 998                    5                   5                    100
# 999                    4                   4                     89
#
#      sleep_hours  exercise_frequency  mental_health_rating  gender_Male  \
# 0              8                   6                     8            0
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
Xlabeled=scaler.fit_transform(Xlabeled)

# %%
Xlabeled
# Out:
# array([[-2.41806844, -1.26653565,  0.09242597, ..., -0.89906522,
#         -0.43967877,  1.46446375],
#        [ 2.28170684,  0.48455058,  1.40169634, ..., -0.89906522,
#         -0.43967877, -0.6828438 ],
#        [-1.46449085,  0.04677902,  1.13558447, ..., -0.89906522,
#          2.27438772, -0.6828438 ],
#        ...,
#        [-0.37468788, -0.26591495, -2.36644764, ...,  1.11226636,
#         -0.43967877,  1.46446375],
#        [ 1.26001656,  0.54708937,  1.68909715, ..., -0.89906522,
#         -0.43967877, -0.6828438 ],
#        [ 0.51077703,  0.29693419,  0.56078285, ..., -0.89906522,
#         -0.43967877, -0.6828438 ]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import  r2_score,mean_absolute_percentage_error

# %%
X_train, X_test, y_train, y_test = train_test_split(Xlabeled, y, test_size=0.20, random_state=42)

# %%
models={
    'linear Regression':LinearRegression(),
    'KNN':KNeighborsRegressor(),
    'Decision Tree':DecisionTreeRegressor(),
    'Random Forest':RandomForestRegressor(),
    'XGBOOST Regressor':XGBRegressor()
}

# %%
result=[]

# %%
for name, model in models.items():
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    r2=r2_score(y_test,y_pred)
    mape=mean_absolute_percentage_error(y_test,y_pred)
    y_pred_train=model.predict(X_train)
    r2_tr=r2_score(y_train,y_pred_train)
    mape_tr=mean_absolute_percentage_error(y_train,y_pred_train)
    result.append({
        "model":name,
        "R2 Score_Test":round(r2,4),
        "MAPE_Test":round(mape,4),
        "R2 Score_Train":round(r2_tr,4),
        "MAPE_Train":round(mape_tr,4)
    })

# %%
print(result)
# Out:
# [{'model': 'linear Regression', 'R2 Score_Test': 0.8974, 'MAPE_Test': 0.0689, 'R2 Score_Train': 0.9016, 'MAPE_Train': 0.0654}, {'model': 'KNN', 'R2 Score_Test': 0.5572, 'MAPE_Test': 0.1445, 'R2 Score_Train': 0.6969, 'MAPE_Train': 0.1214}, {'model': 'Decision Tree', 'R2 Score_Test': 0.7018, 'MAPE_Test': 0.1113, 'R2 Score_Train': 1.0, 'MAPE_Train': 0.0}, {'model': 'Random Forest', 'R2 Score_Test': 0.86, 'MAPE_Test': 0.0801, 'R2 Score_Train': 0.9818, 'MAPE_Train': 0.0289}, {'model': 'XGBOOST Regressor', 'R2 Score_Test': 0.8673, 'MAPE_Test': 0.0783, 'R2 Score_Train': 0.9998, 'MAPE_Train': 0.0023}]

# %%
import joblib
joblib.dump(models["linear Regression"],"linearRegression.pkl")
joblib.dump(scaler,"ScalerLR.pkl")
joblib.dump(X.columns.tolist(),'ColumnsLR.pkl')
# Out:
# ['ColumnsLR.pkl']

# %%
columns=['gender','part_time_job','diet_quality','parental_education_level','internet_quality','extracurricular_participation']
Xlabel=X.copy()
label_encoders={}
for i in columns:
    encoder=LabelEncoder()
    Xlabel[i]=encoder.fit_transform(Xlabel[i].astype(str))
    label_encoders[i]=encoder

# %%
Xlabel
# Out:
#      gender  study_hours_per_day  social_media_hours  part_time_job  \
# 0         0                  0.0                 2.3              0
# 1         0                  6.9                 5.1              0
# 2         1                  1.4                 4.4              0
# 3         0                  1.0                 4.9              0
# 4         0                  5.0                 4.9              0
# ..      ...                  ...                 ...            ...
# 995       0                  2.6                 2.1              0
# 996       0                  2.9                 3.4              1
# 997       1                  3.0                 3.9              0
# 998       1                  5.4                 5.2              1
# 999       0                  4.3                 4.8              0
#
#      attendance_percentage  sleep_hours  diet_quality  exercise_frequency  \
# 0                     85.0          8.0             0                   6
# ...

# %%
from sklearn.preprocessing import StandardScaler
#numeric_cols=['study_hours_per_day','social_media_hours','attendance_percentage','sleep_hours','exercise_frequency','mental_health_rating']
scaler=StandardScaler()
#Xlabel[numeric_cols]=scaler.fit_transform(Xlabel[numeric_cols])

# %%
Xlabel=scaler.fit_transform(Xlabel)

# %%
Xlabel
# Out:
# array([[-0.97616309, -2.41806844, -1.26653565, ..., -1.08974966,
#          0.90018637,  1.46446375],
#        [-0.97616309,  2.28170684,  0.48455058, ..., -1.08974966,
#          0.90018637, -0.6828438 ],
#        [ 0.76387807, -1.46449085,  0.04677902, ...,  1.7370977 ,
#         -1.55933923, -0.6828438 ],
#        ...,
#        [ 0.76387807, -0.37468788, -0.26591495, ...,  0.32367402,
#          1.25154717,  1.46446375],
#        [ 0.76387807,  1.26001656,  0.54708937, ..., -1.08974966,
#         -1.55933923, -0.6828438 ],
#        [-0.97616309,  0.51077703,  0.29693419, ..., -1.08974966,
#          0.90018637, -0.6828438 ]])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import  r2_score,mean_absolute_percentage_error

# %%
X_train, X_test, y_train, y_test = train_test_split(Xlabel, y, test_size=0.20, random_state=42)

# %%
model_lr=LinearRegression()
model_lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_train
# Out:
# array([[-0.97616309, -1.05581473,  1.67278766, ...,  1.7370977 ,
#          1.60290797,  1.46446375],
#        [-0.97616309,  1.94114342,  0.85978334, ...,  0.32367402,
#          0.19746477, -0.6828438 ],
#        [-0.97616309, -0.71525131, -0.51607013, ...,  0.32367402,
#          0.90018637, -0.6828438 ],
#        ...,
#        [-0.97616309,  0.03398823,  2.36071439, ...,  1.7370977 ,
#          0.90018637,  1.46446375],
#        [ 0.76387807, -1.05581473, -0.7662253 , ..., -1.08974966,
#         -0.85661763,  1.46446375],
#        [ 0.76387807,  0.51077703,  0.29693419, ..., -1.08974966,
#         -1.55933923, -0.6828438 ]])

# %%
y_pred=model_lr.predict(X_test)

# %%
y_pred
# Out:
# array([ 66.27133243,  75.36708606,  77.12891886,  73.84718359,
#         60.87049162,  55.35045913,  75.82669581,  55.31354277,
#         41.38448506,  72.7666814 ,  41.3368739 , 102.17474718,
#         58.45207617,  72.25390023,  35.82683353,  56.99098774,
#         73.68136095,  69.11050696,  66.08646387,  50.11111905,
#         56.18535715,  62.50770864,  50.28705028,  87.80318511,
#         69.56893954,  71.42601168,  69.14991331,  56.19226322,
#         69.88456267,  67.80934926,  65.85657336,  78.62117885,
#         64.30083934,  81.05201326,  60.67191178,  50.61149121,
#         70.64640743,  58.45876429,  65.077267  ,  97.44499808,
#         50.4931811 ,  86.19162774,  67.53053903,  64.18455141,
#         94.59749762,  82.32270468,  52.93825555,  79.07260546,
#         63.73167927,  64.50965803,  66.46622774,  47.32171556,
#         70.77754615,  78.36925706,  45.2250089 ,  75.59368762,
#         73.62414484,  68.92252329,  64.06165957,  48.58173743,
# ...

# %%
r2=r2_score(y_test,y_pred)
r2
# Out:
# 0.897819933204004

# %%
n=X_test.shape[0]
p=X_test.shape[1]
adjusted_r2=1-((1-r2)*(n-1)/(n-p-1))
adjusted_r2
# Out:
# 0.8912629235700363

# %%
mape_test=mean_absolute_percentage_error(y_test,y_pred)
mape_test
# Out:
# 0.06884541131984433

# %%
y_pred_train=model_lr.predict(X_train)

# %%
r2=r2_score(y_train,y_pred_train)
r2
# Out:
# 0.9013558124100729

# %%
mape_train=mean_absolute_percentage_error(y_train,y_pred_train)
mape_train
# Out:
# 0.06538214736625775

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model_knn=KNeighborsRegressor()
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_knn=model_knn.predict(X_test)

# %%
r2_knn_test=r2_score(y_test,y_pred_knn)
r2_knn_test
# Out:
# 0.6524120570155579

# %%
mape_knn_test=mean_absolute_percentage_error(y_test,y_pred_knn)
mape_knn_test
# Out:
# 0.12784378875074276

# %%
y_pred_knn_train=model_knn.predict(X_train)

# %%
r2_knn_train=r2_score(y_train,y_pred_knn_train)
r2_knn_train
# Out:
# 0.7665177746241926

# %%
mape_knn_train=mean_absolute_percentage_error(y_train,y_pred_knn_train)
mape_knn_train
# Out:
# 0.1061523798362622

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_dt=DecisionTreeRegressor()
model_dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt=model_dt.predict(X_test)

# %%
r2_dt_test=r2_score(y_test,y_pred_dt)
r2_dt_test
# Out:
# 0.6798773958162688

# %%
mape_dt_test=mean_absolute_percentage_error(y_test,y_pred_dt)
mape_dt_test
# Out:
# 0.11402646629475477

# %%
y_pred_dt_train=model_dt.predict(X_train)

# %%
r2_dt_train=r2_score(y_train,y_pred_dt_train)
r2_dt_train
# Out:
# 1.0

# %%
mape_dt_train=mean_absolute_percentage_error(y_train,y_pred_dt_train)
mape_dt_train
# Out:
# 0.0

# %%
y_train
# Out:
# 29     75.7
# 535    85.0
# 695    68.5
# 557    69.9
# 836    58.7
#        ...
# 106    82.3
# 270    63.0
# 860    65.6
# 435    58.3
# 102    60.8
# Name: exam_score, Length: 800, dtype: float64

# %%
y_pred_dt_train
# Out:
# array([ 75.7,  85. ,  68.5,  69.9,  58.7,  66.1,  39. ,  71.9,  49.9,
#         83.9,  69.6,  96.2,  53.6,  87.5,  57.6, 100. ,  64.4,  58.4,
#         55.4,  53.2,  87.5,  75.2,  66.7,  96.5,  58.4,  34.3,  87.9,
#         54. ,  73. ,  40.4,  81.7,  41.7,  84.6,  48.3,  70.7,  51.3,
#         73.1,  53.3,  69.4,  72.3,  26.8,  78.4,  87.1,  66.3, 100. ,
#         77.5,  35.7,  57.2,  51.3,  46.6,  60.2,  85.3,  78. ,  45.4,
#         69.1,  70.2,  71.2,  69.1,  44.3, 100. ,  63.6,  83.2,  80.9,
#        100. ,  81.9,  77.8,  90.6,  67.7,  80.9, 100. ,  63.6,  58.3,
#         82.1, 100. ,  61.7, 100. ,  64.5,  35.8,  57.6,  77.9,  71.4,
#        100. ,  52.5,  75.9,  98.3,  66.3, 100. ,  74. ,  96.6,  50.8,
#         55. ,  33.6,  74.9,  85.3,  67.9,  66.8,  62. ,  52.4,  72.6,
#         57.3,  67.4,  76.1,  67. ,  29.5, 100. ,  84.5, 100. ,  61.7,
#         89.3,  93.1,  88. ,  80.9,  68.5,  92. ,  91.9,  63.4,  72.6,
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_rf=RandomForestRegressor()
model_rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf=model_rf.predict(X_test)

# %%
r2_rf_test=r2_score(y_test,y_pred_rf)
r2_rf_test
# Out:
# 0.8572569244638291

# %%
mape_rf_test=mean_absolute_percentage_error(y_test,y_pred_rf)
mape_rf_test
# Out:
# 0.08071821032171891

# %%
y_pred_rf_train=model_rf.predict(X_train)

# %%
r2_rf_train=r2_score(y_train,y_pred_rf_train)
r2_rf_train
# Out:
# 0.9812244983107109

# %%
mape_rf_train=mean_absolute_percentage_error(y_train,y_pred_rf_train)
mape_rf_train
# Out:
# 0.02888312184749721

# %%
from xgboost import XGBRegressor

# %%
model_xgb=XGBRegressor()
model_xgb.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb=model_xgb.predict(X_test)

# %%
r2_xgb_test=r2_score(y_test,y_pred_xgb)
r2_xgb_test
# Out:
# 0.8552206655826045

# %%
mape_xgb_test=mean_absolute_percentage_error(y_test,y_pred_xgb)
mape_xgb_test
# Out:
# 0.08020581204237245

# %%
y_pred_xgb_train=model_xgb.predict(X_train)

# %%
r2_xgb_train=r2_score(y_train,y_pred_xgb_train)
r2_xgb_train
# Out:
# 0.9999232083269876

# %%
mape_xgb_train=mean_absolute_percentage_error(y_train,y_pred_xgb_train)
mape_xgb_train
# Out:
# 0.0015403948240119481

# %%
models={
    'linear Regression':LinearRegression(),
    'KNN':KNeighborsRegressor(),
    'Decision Tree':DecisionTreeRegressor(),
    'Random Forest':RandomForestRegressor(),
    'XGBOOST Regressor':XGBRegressor()
}

# %%
result=[]

# %%
for name, model in models.items():
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    r2=r2_score(y_test,y_pred)
    mape=mean_absolute_percentage_error(y_test,y_pred)
    result.append({
        "model":name,
        "R2 Score":round(r2,4),
        "MAPE":round(mape,4)
    })

# %%
result
# Out:
# [{'model': 'linear Regression', 'R2 Score': 0.8978, 'MAPE': 0.0688},
#  {'model': 'KNN', 'R2 Score': 0.6524, 'MAPE': 0.1278},
#  {'model': 'Decision Tree', 'R2 Score': 0.6761, 'MAPE': 0.113},
#  {'model': 'Random Forest', 'R2 Score': 0.855, 'MAPE': 0.0819},
#  {'model': 'XGBOOST Regressor', 'R2 Score': 0.8552, 'MAPE': 0.0802}]

# %%
import joblib
joblib.dump(models["linear Regression"],"linear_Reg_Stu_habit_Perfom.pkl")
joblib.dump(scaler,"scaler.pkl")
joblib.dump(X.columns.tolist(),'columns.pkl')
# Out:
# ['columns.pkl']
